# %%
# %matplotlib inline

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pydicom
import os
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# %%
#scan all the slides of one patient, load all slides, sort them in Z axis, return slice_thickness
def load_scan(path):
    slices = [pydicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: float(x.ImagePositionPatient[2]))
    try:
        slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
    except:
        slice_thickness = np.abs(slices[0].SliceLocation - slices[1].SliceLocation)

    for s in slices:
        s.SliceThickness = slice_thickness

    return slices

# %%
def get_pixels_hu(slices):
    image = np.stack([s.pixel_array for s in slices])
    # all data should <32k
    image = image.astype(np.int16)
    # Set outside-of-scan pixels to 0
    # The intercept is usually -1024, so air is approximately 0
    image[image == -2000] = 0

    # Convert to Hounsfield units (HU)
    for slice_number in range(len(slices)):

        intercept = slices[slice_number].RescaleIntercept
        slope = slices[slice_number].RescaleSlope

        if slope != 1:
            image[slice_number] = slope * image[slice_number].astype(np.float64)
            image[slice_number] = image[slice_number].astype(np.int16)

        image[slice_number] += np.int16(intercept)

    return np.array(image, dtype=np.int16)

# %% [markdown]
# # read ct and contour image

# %%
INPUT_FOLDER = '../'
patients = os.listdir(INPUT_FOLDER)
print(patients)
organ=os.listdir(INPUT_FOLDER+patients[0])
print(organ)
path1=INPUT_FOLDER+patients[0]+"/"+organ[0]
path2=INPUT_FOLDER+patients[0]+"/"+organ[2]
print(path1)
print(path2)
# Out:
# ['02-28-1994-CT NECK SOFT TISSUE  W CONTR-40819']
# ['3.000000-NeckST MPR  3.0  B30s-75963', '4.000000-NeckST MPR  3.0  B70s-75783', '602.000000-st coronals X 3s MPR Range-87966', 'Untitled.ipynb']
# ../02-28-1994-CT NECK SOFT TISSUE  W CONTR-40819/3.000000-NeckST MPR  3.0  B30s-75963
# ../02-28-1994-CT NECK SOFT TISSUE  W CONTR-40819/602.000000-st coronals X 3s MPR Range-87966

# %%
##full ct
ct = load_scan(path1)
ct_pixels = get_pixels_hu(ct)
plt.hist(ct_pixels.flatten(), bins=80, color='c')
plt.xlabel("Hounsfield Units (HU)")
plt.ylabel("Frequency")
plt.show()

# %%
##contour
contour = load_scan(path2)
contour_pixels = get_pixels_hu(contour)
plt.hist(contour_pixels.flatten(), bins=80, color='c')
plt.xlabel("Hounsfield Units (HU)")
plt.ylabel("Frequency")
plt.show()

# %%
def sample_stack(stack, rows=5, cols=5, start_with=1, show_every=2):
    fig,ax = plt.subplots(rows,cols,figsize=[12,12])
    for i in range(rows*cols):
        ind = start_with + i*show_every
        ax[int(i/rows),int(i % rows)].set_title('slice %d' % ind)
        ax[int(i/rows),int(i % rows)].imshow(stack[ind],cmap='gray')
        ax[int(i/rows),int(i % rows)].axis('off')
    plt.show()

# %%
id=0
np.save(path1 + "fullimages_%d.npy" % (id), ct_pixels)

ct_image = np.load(path1+'fullimages_{}.npy'.format(id))
sample_stack(ct_image)

# %%
id=0
np.save(path2 + "contourimages_%d.npy" % (id), contour_pixels)

contour_image = np.load(path2+'contourimages_{}.npy'.format(id))
sample_stack(contour_image)

# %%
print("Slice Thickness: %f" % ct[0].SliceThickness)
print("Pixel Spacing (row, col): (%f, %f) " % (ct[0].PixelSpacing[0], ct[0].PixelSpacing[1]))
# Out:
# Slice Thickness: 3.000000
# Pixel Spacing (row, col): (0.484375, 0.484375)

# %% [markdown]
# This means we have 3.0m slices, and each voxel represents 0.48 mm.

# %% [markdown]
# # rescale

# %%
def resample(image, scan, new_spacing=[1,1,1]):
    # Determine current pixel spacing
    spacing = map(float, ([scan[0].SliceThickness] + list(scan[0].PixelSpacing)))
    spacing = np.array(list(spacing))

    resize_factor = spacing / new_spacing
    new_real_shape = image.shape * resize_factor
    new_shape = np.round(new_real_shape)
    real_resize_factor = new_shape / image.shape
    new_spacing = spacing / real_resize_factor
    
    image = scipy.ndimage.interpolation.zoom(image, real_resize_factor)
    
    return image, new_spacing

# %%
id = 0
ct_imgs = np.load(path1+'fullimages_{}.npy'.format(id))

print("Shape before resampling\t", ct_imgs.shape)
ct_after_resamp, spacing = resample(ct_imgs, ct, [1,1,1])
print("Shape after resampling\t", ct_after_resamp.shape)
# Out:
# Shape before resampling	 (89, 512, 512)
# Shape after resampling	 (267, 248, 248)

# %%
id = 0
contour_imgs = np.load(path2+'contourimages_{}.npy'.format(id))

print("Shape before resampling\t", contour_imgs.shape)
contour_after_resamp, spacing = resample(contour_imgs, contour, [1,1,1])
print("Shape after resampling\t", contour_after_resamp.shape)
# Out:
# Shape before resampling	 (60, 512, 512)
# C:\Users\73707\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# Shape after resampling	 (0, 267, 267)

# %% [markdown]
# # 3d plotting

# %%
def make_mesh(image, threshold=-300, step_size=1):

    print("Transposing surface")
    p = image.transpose(2,1,0)
    
    print("Calculating surface")
    verts, faces, norm, val = measure.marching_cubes_lewiner(p, threshold, step_size=step_size, allow_degenerate=True) 
    return verts, faces
def plt_3d(verts, faces):
    print("Drawing")
    x,y,z = zip(*verts) 
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')

    # Fancy indexing: `verts[faces]` to generate a collection of triangles
    mesh = Poly3DCollection(verts[faces], linewidths=0.05, alpha=1)
    face_color = [0.45, 0.45, 0.75]
    mesh.set_facecolor(face_color)
    ax.add_collection3d(mesh)

    ax.set_xlim(0, max(x))
    ax.set_ylim(0, max(y))
    ax.set_zlim(0, max(z))
    
    plt.show()

# %%
v, f = make_mesh(ct_after_resamp, 300)
plt_3d(v, f)
# Out:
# Transposing surface
# Calculating surface
# Drawing

# %%
v, f = make_mesh(contour_imgs, 300)
plt_3d(v, f)
# Out:
# Transposing surface
# Calculating surface
# Drawing

# %% [markdown]
# # locate contour

# %%
def largest_label_volume(im, bg=-1):
    vals, counts = np.unique(im, return_counts=True)

    counts = counts[vals != bg]
    vals = vals[vals != bg]

    if len(counts) > 0:
        return vals[np.argmax(counts)]
    else:
        return None

# %%
def segment_mask(image):

    # not actually binary, but 1 and 2. 
    # 0 is treated as background, which we do not want   
    binary_image = np.array(image > -320, dtype=np.int8)+1
    labels = measure.label(binary_image)

    # Pick the pixel in the very corner to determine which label is air.
    #   Improvement: Pick multiple background labels from around the patient
    #   More resistant to "trays" on which the patient lays cutting the air 
    #   around the person in half
    background_label = labels[0,0,0]

    #Fill the air around the person
    binary_image[background_label == labels] = 1
    
    binary_image -= 1 #Make the image actual binary

    # Remove other air pockets insided body
    labels = measure.label(binary_image, background=0)
    l_max = largest_label_volume(labels, bg=0)
    if l_max is not None: # There are air pockets
        binary_image[labels != l_max] = 0

    return binary_image

# %%
segmented_img1 = segment_lung_mask(contour_imgs)

# %%
v, f = make_mesh(segmented_img1, 0)
plt_3d(v, f)
# Out:
# Transposing surface
# Calculating surface
# Drawing

# %%
segmented_img2 = segment_lung_mask(ct_after_resamp)
v, f = make_mesh(segmented_img2, 0)
plt_3d(v, f)
# Out:
# Transposing surface
# Calculating surface
# Drawing

# %% [markdown]
# # define parameters

# %%
k=1
voxel=segmented_img[k]
loci=np.where(voxel>0)
cord=np.stack((loci[0], loci[1]), axis=-1)

# %%
voxel.shape
# Out:
# (512, 512)

# %%
# sd set as (1.7,2,2.5)
SD_x=1.7
SD_y=2
SD_z=2.5

from scipy.stats import norm
pRand_k=np.random.uniform()
Fsd_x=norm.ppf(pRand_k, loc=0, scale=SD_x)
Fsd_y=norm.ppf(pRand_k, loc=0, scale=SD_y)
Fsd_z=norm.ppf(pRand_k, loc=0, scale=SD_z)
