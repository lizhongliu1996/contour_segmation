# %%
# %matplotlib inline

from dicom_utils import *
import numpy as np 
import pandas as pd 
import os
import pydicom
import matplotlib.pyplot as plt
#import assd_func as af
from skimage import morphology
import matplotlib.patches as mpatches
import assd_func_Sobel_2 as af_Sobel
import time
import random
from scipy.stats import uniform,norm

# %%
organ = "rectum" #Change this your organ

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/1"
organ_i = 4
output_dir = "Output"
images_1, slices_1, contours_1, labels_1, dummy_mask_1 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/3"
output_dir = "Output"
images_3, slices_3, contours_3, labels_3, dummy_mask_3 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/4"
output_dir = "Output"
images_4, slices_4, contours_4, labels_4, dummy_mask_4 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/5"
output_dir = "Output"
images_5, slices_5, contours_5, labels_5, dummy_mask_5 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/6"
output_dir = "Output"
images_6, slices_6, contours_6, labels_6, dummy_mask_6 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/7"
output_dir = "Output"
images_7, slices_7, contours_7, labels_7, dummy_mask_7 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/8"
output_dir = "Output"
images_8, slices_8, contours_8, labels_8, dummy_mask_8 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/9"
output_dir = "Output"
images_9, slices_9, contours_9, labels_9, dummy_mask_9 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/10"
output_dir = "Output"
images_10, slices_10, contours_10, labels_10, dummy_mask_10 = main(dicom_dir, output_dir)

# %% [markdown]
# # Rectum

# %%
len(contours_1)

# %%
def find_roi_slices(images, labels, i):
    roi_z = []
    for j in range(images.shape[0]):
        if True in np.unique(labels[..., i][j, ...] > 0):
            roi_z.append(j)
    return roi_z

def find_organ_i(organ, contours):
    organ = "rectum"
    contour_table = pd.DataFrame()
    number = []
    name = []
    for i in range(len(contours)):
        number.append(contours[i]["number"])
        name.append(contours[i]["name"])
    #contour_table["number"] = number
    contour_table["name"] = name
    contour_table
    organ_i =  contour_table[contour_table["name"].str.contains(organ)].index.tolist()[0]
    return organ_i

# %%
organ_i_1 =  find_organ_i(organ, contours_1)
organ_i_1

# %%
roi_z_1 = find_roi_slices(images_1, labels_1, organ_i_1)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_1[i + roi_z_1[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_1[..., organ_i_1][i + 63, ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %% [markdown]
# plt.figure(figsize=(15, 15))
# for i in range(9):
#     plt.subplot(3, 3, i + 1)
#     plt.imshow(images_2[i + 63, ...], cmap="gray", vmin=-250, vmax=250)
#     plt.contour(labels_2[..., organ_i][i + 63, ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
# plt.axis('off')

# %%
organ_i_3 =  find_organ_i(organ, contours_3)
organ_i_3

# %%
roi_z_3 = find_roi_slices(images_3, labels_3, organ_i_3)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_3[i + roi_z_3[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_3[..., organ_i_3][i + roi_z_3[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %%
organ_i_4 =  find_organ_i(organ, contours_4)
organ_i_4

# %%
roi_z_4 = find_roi_slices(images_4, labels_4, organ_i_4)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_4[i + roi_z_4[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_4[..., organ_i_4][i + roi_z_4[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %%
organ_i_5 =  find_organ_i(organ, contours_5)
organ_i_5

# %%
roi_z_5 = find_roi_slices(images_5, labels_5, organ_i_5)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_5[i + roi_z_5[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_5[..., organ_i_5][i + roi_z_5[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %%
organ_i_6 =  find_organ_i(organ, contours_6)
organ_i_6

# %%
roi_z_6 = find_roi_slices(images_6, labels_6, organ_i_6)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_6[i + roi_z_6[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_6[..., organ_i_6][i + roi_z_6[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %%
organ_i_7 =  find_organ_i(organ, contours_7)
organ_i_7

# %%
roi_z_7 = find_roi_slices(images_7, labels_7, organ_i_7)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_7[i + roi_z_7[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_7[..., organ_i_7][i + roi_z_7[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %%
organ_i_8 =  find_organ_i(organ, contours_8)
organ_i_8

# %%
roi_z_8 = find_roi_slices(images_8, labels_8, organ_i_8)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_8[i + roi_z_8[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_8[..., organ_i_8][i + roi_z_8[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')

# %%
organ_i_9 =  find_organ_i(organ, contours_9)
organ_i_9

# %%
roi_z_9 = find_roi_slices(images_9, labels_9, organ_i_9)

# %%
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_9[i + roi_z_9[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_9[..., organ_i_9][i + roi_z_9[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
organ_i_10 =  find_organ_i(organ, contours_10)
organ_i_10
# Out:
# 9

# %%
roi_z_10 = find_roi_slices(images_10, labels_10, organ_i_10)

# %%
organ_i = 4
plt.figure(figsize=(15, 15))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images_10[i + roi_z_10[0], ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(labels_10[..., organ_i_10][i + roi_z_10[0], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
plt.axis('off')
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# ## Paremeter Experimentation

# %%
def dice_coef(seg, gt, k=1):
    dice = np.sum(seg[gt==k])*2.0 / (np.sum(seg) + np.sum(gt))
    return dice

def create_log(df, c, k, w, ismax, dice):
    if ismax:
        ismax = "max"
    else: 
        ismax = "min"
    df = df.append({'c' : c, 'k' : k, 'w': w, 'min/max' : ismax, 'dice': dice},  
                ignore_index = True) 
    return df

# %%
target_img4 = images_4[roi_z_4[2], ...]
target_label4 = labels_4[..., organ_i_4][roi_z_4[2], ...]
plt.figure(figsize=(5, 5))
plt.imshow(target_img4, cmap="gray", vmin=-240, vmax=240)
plt.contour(target_label4, levels=[0.4, 1.4, 2.4, 3.4, 1.4], colors="green")
plt.xlim(200, 300)
plt.ylim(320, 250)
plt.axis("off")
# Out:
# (200.0, 300.0, 320.0, 250.0)

# %%
target_img1 = images_1[roi_z_1[2], ...]
target_label1 = labels_1[..., organ_i_1][roi_z_1[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 10, 15, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 1
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
ismax=True
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask1, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img1, target_label1, voxelsize, a, SD, circles, seed, k, w, images_1, labels_1, organ_i_1, ismax=ismax, smooth=True)
    du1 = af_Sobel.plotting_assd(dx, dy, mask1, target_img1, quiver=False, plot=False)
    dice = dice_coef(du1, target_label1, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img1, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label1, levels=[0.5, 1.5, 2.5, 3.5, 1.5], colors="green")
    plt.contour(du1, levels=[0.5, 1.5, 2.5, 3.5, 1.5], colors="red")
    plt.xlim(280, 230)
    plt.ylim(320, 260)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
import time
target_img3 = images_3[roi_z_3[2], ...]
target_label3 = labels_3[..., organ_i_3][roi_z_3[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 30, 35, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
start = time.time()
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask3, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img3, target_label3, voxelsize, a, SD, circles, seed, k, w, images_3, labels_3, organ_i_3, ismax=ismax, smooth=True)
    du3 = af_Sobel.plotting_assd(dx, dy, mask3, target_img3, quiver=False, plot=False)
    dice = dice_coef(du3, target_label3, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img3, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label3, levels=[0.5, 1.5, 2.5, 3.5, 3.5], colors="green")
    plt.contour(du3, levels=[0.5, 1.5, 2.5, 3.5, 3.5], colors="red")
    plt.xlim(300, 150)
    plt.ylim(350, 250)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()
end = time.time()
print(end - start)
# Out:
# 1130.5615510940552

# %%
target_img4 = images_4[roi_z_4[1], ...]
target_label4 = labels_4[..., organ_i_4][roi_z_4[1], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask4, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img4, target_label4, voxelsize, a, SD, circles, seed, k, w, images_4, labels_4, organ_i_4, ismax=ismax, smooth=True)
    du4 = af_Sobel.plotting_assd(dx, dy, mask4, target_img4, quiver=False, plot=False)
    dice = dice_coef(du4, target_label4, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img4, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label4, levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="green")
    plt.contour(du4, levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="red")
    plt.xlim(200, 300)
    plt.ylim(320, 250)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
target_img5 = images_5[roi_z_5[2], ...]
target_label5 = labels_5[..., organ_i_5][roi_z_5[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 50, 55, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask5, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img5, target_label5, voxelsize, a, SD, circles, seed, k, w, images_5, labels_5, organ_i_5, ismax=ismax, smooth=True)
    du5 = af_Sobel.plotting_assd(dx, dy, mask5, target_img5, quiver=False, plot=False)
    dice = dice_coef(du5, target_label5, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img5, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label5, levels=[0.5, 1.5, 2.5, 3.5, 5.5], colors="green")
    plt.contour(du5, levels=[0.5, 1.5, 2.5, 3.5, 5.5], colors="red")
    plt.xlim(200, 270)
    plt.ylim(360, 270)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()
# Out:
# /home/vily/.conda/envs/env/lib/python3.7/site-packages/matplotlib/contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
target_img6 = images_6[roi_z_6[2], ...]
target_label6 = labels_6[..., organ_i_6][roi_z_6[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 60, 65, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask6, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img6, target_label6, voxelsize, a, SD, circles, seed, k, w, images_6, labels_6, organ_i_6, ismax=ismax, smooth=True)
    du6 = af_Sobel.plotting_assd(dx, dy, mask6, target_img6, quiver=False, plot=False)
    dice = dice_coef(du6, target_label6, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img6, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label6, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="green")
    plt.contour(du6, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="red")
    plt.xlim(220, 270)
    plt.ylim(330, 270)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
target_img7 = images_7[roi_z_7[2], ...]
target_label7 = labels_7[..., organ_i_7][roi_z_7[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 60, 65, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask7, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img7, target_label7, voxelsize, a, SD, circles, seed, k, w, images_7, labels_7, organ_i_7, ismax=ismax, smooth=True)
    du7 = af_Sobel.plotting_assd(dx, dy, mask7, target_img7, quiver=False, plot=False)
    dice = dice_coef(du7, target_label7, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img7, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label7, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="green")
    plt.contour(du7, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="red")
    plt.xlim(230, 280)
    plt.ylim(300, 260)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
target_img8 = images_8[roi_z_8[2], ...]
target_label8 = labels_8[..., organ_i_8][roi_z_8[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 60, 65, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask8, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img8, target_label8, voxelsize, a, SD, circles, seed, k, w, images_8, labels_8, organ_i_8, ismax=ismax, smooth=True)
    du8 = af_Sobel.plotting_assd(dx, dy, mask8, target_img8, quiver=False, plot=False)
    dice = dice_coef(du8, target_label8, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img8, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label8, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="green")
    plt.contour(du8, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="red")
    plt.xlim(230, 280)
    plt.ylim(300, 260)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
target_img9 = images_9[roi_z_9[2], ...]
target_label9 = labels_9[..., organ_i_9][roi_z_9[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 60, 65, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask9, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img9, target_label9, voxelsize, a, SD, circles, seed, k, w, images_9, labels_9, organ_i_9, ismax=ismax, smooth=True)
    du9 = af_Sobel.plotting_assd(dx, dy, mask9, target_img9, quiver=False, plot=False)
    dice = dice_coef(du9, target_label9, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img9, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label9, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="green")
    plt.contour(du9, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="red")
    plt.xlim(200, 270)
    plt.ylim(320, 250)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
target_img10 = images_10[roi_z_10[2], ...]
target_label10 = labels_10[..., organ_i_10][roi_z_10[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.1076562, 0.1076562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 60, 65, 50, 55, 60, 65, 70, 75, 80, 100, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask10, t1, L1, roi_z = af_Sobel.assd_Sobel(target_img10, target_label10, voxelsize, a, SD, circles, seed, k, w, images_10, labels_10, organ_i_10, ismax=ismax, smooth=True)
    du10 = af_Sobel.plotting_assd(dx, dy, mask10, target_img10, quiver=False, plot=False)
    dice = dice_coef(du10, target_label10, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_img10, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_label10, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="green")
    plt.contour(du10, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="red")
    plt.xlim(200, 300)
    plt.ylim(320, 250)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %%
target_imgnum = images_num[roi_z_num[2], ...]
target_labelnum = labels_num[..., organ_i_num][roi_z_num[2], ...]
dice_list = []
a=50
voxelsize = np.array([0.976562, 0.976562, 2.5])
plt.figure(figsize=(15, 15))
c_list = [1, 3, 5, 10, 15, 20, 25, 30, 35, 60, 65, 50, 55, 60, 65, 70, 75, 80, 90, 100]
k = 10
df = pd.DataFrame(columns = ['k', 'c', 'w', 'min/max', "dice"]) 
circles = 3
seed = 123
w = 2
for i in range(len(c_list)):
    #print("c:" +  str(c_list[i]))
    c = c_list[i]
    SD=[c*1.3, c*1.3, c*3]
    dx, dy, mask6, t1, L1, roi_z = af_Sobel.assd_Sobel(target_imgnum, target_labelnum, voxelsize, a, SD, circles, seed, k, w, images_num, labels_num, organ_i_num, ismax=ismax, smooth=True)
    du6 = af_Sobel.plotting_assd(dx, dy, masknum, target_imgnum, quiver=False, plot=False)
    dice = dice_coef(dunum, target_labelnum, 1)
    dice_list.append(dice)
    df = create_log(df, c, k, w, ismax, dice)
    plt.subplot(5, 4, i + 1)
    plt.imshow(target_imgnum, cmap="gray", vmin=-250, vmax=250)
    plt.contour(target_labelnum, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="green")
    plt.contour(dunum, levels=[0.5, 1.5, 2.5, 3.5, 6.5], colors="red")
    plt.xlim(230, 280)
    plt.ylim(300, 250)
    plt.title("c = " + str(c_list[i]))
    plt.axis('off')
destination_path = "C:\\Users\\lykha\\OneDrive\\Documents\\1_PhD_Fall_2020\\Research_MDA\\contour_segmentation\\Output\\log\\"
df.to_csv(destination_path + "Dice_log_Rectum.csv")
# plot dice  
plt.figure(figsize=(5, 5))
plt.plot(c_list, dice_list, label="Dice coef")
plt.ylabel("Dice")
plt.xlabel("c*[1.7, 2, 2.5]")
plt.legend()

# %% [markdown]
# ## Different slides

# %%
c = 15
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_1 = labels_1[..., roi_i_1].copy()
seed = 123

for i in roi_z:
    dx, dy, mask1, t, L, roi_z = af_Sobel.assd_Sobel(images_1[i, ...], labels+1[..., roi_i_1][i, ...], voxelsize, a, SD, circles, seed, k, w, images_1, labels_1, roi_1ber, ismax=ismax, smooth=True)
    du1 = af_Sobel.plotting_assd(dx, dy, mask1, images_1[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du1  
assd_contour_rectum_1 = np.array(assd_contour_rectum_1)

plt.figure(figsize=(15, 15))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(images_1[roi_z_1[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_1[roi_z_1[i], ...], levels = [0.5, 1.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_1[..., roi_i_1][roi_z_1[i], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 1')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_3 = labels_3[..., roi_i_3].copy()
seed = 123

for i in roi_z:
    dx, dy, mask3, t, L, roi_z = af_Sobel.assd_Sobel(images_3[i, ...], labels+3[..., roi_i_3][i, ...], voxelsize, a, SD, circles, seed, k, w, images_3, labels_3, roi_3ber, ismax=ismax, smooth=True)
    du3 = af_Sobel.plotting_assd(dx, dy, mask3, images_3[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du3  
assd_contour_rectum_3 = np.array(assd_contour_rectum_3)

plt.figure(figsize=(15, 15))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(images_3[roi_z_3[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_3[roi_z_3[i], ...], levels = [0.5, 1.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_3[..., roi_i_3][roi_z_3[i], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 1')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_4 = labels_4[..., roi_i_4].copy()
seed = 123

for i in roi_z:
    dx, dy, mask4, t, L, roi_z = af_Sobel.assd_Sobel(images_4[i, ...], labels+4[..., roi_i_4][i, ...], voxelsize, a, SD, circles, seed, k, w, images_4, labels_4, roi_4ber, ismax=ismax, smooth=True)
    du4 = af_Sobel.plotting_assd(dx, dy, mask4, images_4[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du4  
assd_contour_rectum_4 = np.array(assd_contour_rectum_4)

plt.figure(figsize=(15, 15))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(images_4[roi_z_4[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_4[roi_z_4[i], ...], levels = [0.5, 1.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_4[..., roi_i_4][roi_z_4[i], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 1')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_5 = labels_5[..., roi_i_5].copy()
seed = 123

for i in roi_z:
    dx, dy, mask5, t, L, roi_z = af_Sobel.assd_Sobel(images_5[i, ...], labels+5[..., roi_i_5][i, ...], voxelsize, a, SD, circles, seed, k, w, images_5, labels_5, roi_5ber, ismax=ismax, smooth=True)
    du5 = af_Sobel.plotting_assd(dx, dy, mask5, images_5[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du5  
assd_contour_rectum_5 = np.array(assd_contour_rectum_5)

plt.figure(figsize=(15, 15))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.imshow(images_5[roi_z_5[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_5[roi_z_5[i], ...], levels = [0.5, 1.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_5[..., roi_i_5][roi_z_5[i], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 1')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_num = labels_num[..., roi_i_num].copy()
seed = 123

for i in roi_z:
    dx, dy, masknum, t, L, roi_z = af_Sobel.assd_Sobel(images_num[i, ...], labels+num[..., roi_i_num][i, ...], voxelsize, a, SD, circles, seed, k, w, images_num, labels_num, roi_number, ismax=ismax, smooth=True)
    dunum = af_Sobel.plotting_assd(dx, dy, masknum, images_num[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = dunum  
assd_contour_rectum_num = np.array(assd_contour_rectum_num)

plt.figure(figsize=(num5, num5))
for i in range(25):
    plt.subplot(5, 5, i + num)
    plt.imshow(images_num[roi_z_num[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_num[roi_z_num[i], ...], levels = [0.5, num.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_num[..., roi_i_num][roi_z_num[i], ...], levels=[0.5, num.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed num')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_6 = labels_6[..., roi_i_6].copy()
seed = 123

for i in roi_z:
    dx, dy, mask6, t, L, roi_z = af_Sobel.assd_Sobel(images_6[i, ...], labels+6[..., roi_i_6][i, ...], voxelsize, a, SD, circles, seed, k, w, images_6, labels_6, roi_6ber, ismax=ismax, smooth=True)
    du6 = af_Sobel.plotting_assd(dx, dy, mask6, images_6[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du6  
assd_contour_rectum_6 = np.array(assd_contour_rectum_6)

plt.figure(figsize=(65, 65))
for i in range(25):
    plt.subplot(5, 5, i + 6)
    plt.imshow(images_6[roi_z_6[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_6[roi_z_6[i], ...], levels = [0.5, 6.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_6[..., roi_i_6][roi_z_6[i], ...], levels=[0.5, 6.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 6')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_7 = labels_7[..., roi_i_7].copy()
seed = 123

for i in roi_z:
    dx, dy, mask7, t, L, roi_z = af_Sobel.assd_Sobel(images_7[i, ...], labels+7[..., roi_i_7][i, ...], voxelsize, a, SD, circles, seed, k, w, images_7, labels_7, roi_7ber, ismax=ismax, smooth=True)
    du7 = af_Sobel.plotting_assd(dx, dy, mask7, images_7[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du7  
assd_contour_rectum_7 = np.array(assd_contour_rectum_7)

plt.figure(figsize=(75, 75))
for i in range(25):
    plt.subplot(5, 5, i + 7)
    plt.imshow(images_7[roi_z_7[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_7[roi_z_7[i], ...], levels = [0.5, 7.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_7[..., roi_i_7][roi_z_7[i], ...], levels=[0.5, 7.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 7')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_8 = labels_8[..., roi_i_8].copy()
seed = 123

for i in roi_z:
    dx, dy, mask8, t, L, roi_z = af_Sobel.assd_Sobel(images_8[i, ...], labels+8[..., roi_i_8][i, ...], voxelsize, a, SD, circles, seed, k, w, images_8, labels_8, roi_8ber, ismax=ismax, smooth=True)
    du8 = af_Sobel.plotting_assd(dx, dy, mask8, images_8[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du8  
assd_contour_rectum_8 = np.array(assd_contour_rectum_8)

plt.figure(figsize=(85, 85))
for i in range(25):
    plt.subplot(5, 5, i + 8)
    plt.imshow(images_8[roi_z_8[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_8[roi_z_8[i], ...], levels = [0.5, 8.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_8[..., roi_i_8][roi_z_8[i], ...], levels=[0.5, 8.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 8')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_9 = labels_9[..., roi_i_9].copy()
seed = 123

for i in roi_z:
    dx, dy, mask9, t, L, roi_z = af_Sobel.assd_Sobel(images_9[i, ...], labels+9[..., roi_i_9][i, ...], voxelsize, a, SD, circles, seed, k, w, images_9, labels_9, roi_9ber, ismax=ismax, smooth=True)
    du9 = af_Sobel.plotting_assd(dx, dy, mask9, images_9[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du9  
assd_contour_rectum_9 = np.array(assd_contour_rectum_9)

plt.figure(figsize=(95, 95))
for i in range(25):
    plt.subplot(5, 5, i + 9)
    plt.imshow(images_9[roi_z_9[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_9[roi_z_9[i], ...], levels = [0.5, 9.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_9[..., roi_i_9][roi_z_9[i], ...], levels=[0.5, 9.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 9')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')

# %%
k = 15
w = 2
SD=[c*1.3, c*1.3, c*3]
assd_contour_rectum_10 = labels_10[..., roi_i_10].copy()
seed = 123

for i in roi_z:
    dx, dy, mask10, t, L, roi_z = af_Sobel.assd_Sobel(images_10[i, ...], labels+10[..., roi_i_10][i, ...], voxelsize, a, SD, circles, seed, k, w, images_10, labels_10, roi_10ber, ismax=ismax, smooth=True)
    du10 = af_Sobel.plotting_assd(dx, dy, mask10, images_10[i, ...], quiver=False, plot=False) 
    assd_contour_rectum[i, ...] = du10  
assd_contour_rectum_10 = np.array(assd_contour_rectum_10)

plt.figure(figsize=(105, 105))
for i in range(25):
    plt.subplot(5, 5, i + 10)
    plt.imshow(images_10[roi_z_10[i] , ...], cmap="gray", vmin=-250, vmax=250)
    plt.contour(assd_contour_rectum_10[roi_z_10[i], ...], levels = [0.5, 10.5, 2.5, 3.5, 4.5], colors="red")
    plt.contour(labels_10[..., roi_i_10][roi_z_10[i], ...], levels=[0.5, 10.5, 2.5, 3.5, 4.5], colors="blue")
    plt.xlim(270, 220)
    plt.ylim(300, 260)
    blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
    red_patch = mpatches.Patch(color='red', label='DU contour with random seed 10')
    plt.legend(handles=[ blue_patch, red_patch])
plt.axis('off')
