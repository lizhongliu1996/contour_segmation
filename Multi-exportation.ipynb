# %%
# %matplotlib inline

from dicom_utils import *
import numpy as np 
import pandas as pd 
import os
import pydicom
import matplotlib.pyplot as plt
#import assd_func as af
from skimage import morphology
import matplotlib.patches as mpatches
import assd_func_Sobel_2 as af_Sobel
import time
import random
from scipy.stats import uniform,norm

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/1"
output_dir = "Output"
images_1, slices_1, contours_1, labels_1, dummy_mask_1 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/3"
output_dir = "Output"
images_3, slices_3, contours_3, labels_3, dummy_mask_3 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/4"
output_dir = "Output"
images_4, slices_4, contours_4, labels_4, dummy_mask_4 = main(dicom_dir, output_dir)
# Out:
#    Missing contours for structure: sigmoid

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/5"
output_dir = "Output"
images_5, slices_5, contours_5, labels_5, dummy_mask_5 = main(dicom_dir, output_dir)
# Out:
#    Missing contours for structure: CTV_
#    Missing contours for structure: SeminalVes_Dist
#    Missing contours for structure: Hot Spot 7210 cGy (Rectum)
#    Missing contours for structure: Hot Spot 7350 cGy (Total PTV)

# %% [markdown]
# => Patient 5 has no prostate (fossa)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/6"
output_dir = "Output"
images_6, slices_6, contours_6, labels_6, dummy_mask_6 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/7"
output_dir = "Output"
images_7, slices_7, contours_7, labels_7, dummy_mask_7 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/8"
output_dir = "Output"
images_8, slices_8, contours_8, labels_8, dummy_mask_8 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/9"
output_dir = "Output"
images_9, slices_9, contours_9, labels_9, dummy_mask_9 = main(dicom_dir, output_dir)

# %%
dicom_dir = "/home/vily/MRI-Project/contour_segmentation/Prostate Cases/10"
output_dir = "Output"
images_10, slices_10, contours_10, labels_10, dummy_mask_10 = main(dicom_dir, output_dir)
# Out:
#    Missing contours for structure: ROI_1

# %% [markdown]
# # Finding organs ID:

# %%
def find_roi_slices(images, labels, i):
    roi_z = []
    for j in range(images.shape[0]):
        if True in np.unique(labels[..., i][j, ...] > 0):
            roi_z.append(j)
    return roi_z

def find_organ_i(organ, contours):
    contour_table = pd.DataFrame()
    number = []
    name = []
    for i in range(len(contours)):
        number.append(contours[i]["number"])
        name.append(contours[i]["name"])
    #contour_table["number"] = number
    contour_table["name"] = name
    contour_table
    organ_i =  contour_table[contour_table["name"].str.contains(organ)].index.tolist()[0]
    return organ_i

# %% [markdown]
# ## Prostate

# %%
organ = "prostate" #Change this your organ
organ_i_1_p =  find_organ_i(organ, contours_1)
roi_z_1_p = find_roi_slices(images_1, labels_1, organ_i_1_p)
organ_i_3_p =  find_organ_i(organ, contours_3)
roi_z_3_p = find_roi_slices(images_3, labels_3, organ_i_3_p)
organ_i_4_p =  find_organ_i(organ, contours_4)
roi_z_4_p = find_roi_slices(images_4, labels_4, organ_i_4_p)
organ_i_6_p =  find_organ_i(organ, contours_6)
roi_z_6_p = find_roi_slices(images_6, labels_6, organ_i_6_p)
organ_i_7_p =  find_organ_i(organ, contours_7)
roi_z_7_p = find_roi_slices(images_7, labels_7, organ_i_7_p)
organ_i_8_p =  find_organ_i(organ, contours_8)
roi_z_8_p = find_roi_slices(images_8, labels_8, organ_i_8_p)
organ_i_9_p =  find_organ_i(organ, contours_9)
roi_z_9_p = find_roi_slices(images_9, labels_9, organ_i_9_p)
organ_i_10_p =  find_organ_i(organ_p, contours_10)
roi_z_10_p = find_roi_slices(images_10, labels_10, organ_i_10_p)
# Out:
# 1

# %% [markdown]
# ## Rectum

# %%
organ = "rectum" #Change this your organ
organ_i_1_r =  find_organ_i(organ, contours_1)
roi_z_1_r = find_roi_slices(images_1, labels_1, organ_i_1_r)
organ_i_3_r =  find_organ_i(organ, contours_3)
roi_z_3_r = find_roi_slices(images_3, labels_3, organ_i_3_r)
organ_i_4_r =  find_organ_i(organ, contours_4)
roi_z_4_r = find_roi_slices(images_4, labels_4, organ_i_4_r)
organ_i_6_r =  find_organ_i(organ, contours_6)
roi_z_6_r = find_roi_slices(images_6, labels_6, organ_i_6_r)
organ_i_7_r =  find_organ_i(organ, contours_7)
roi_z_7_r = find_roi_slices(images_7, labels_7, organ_i_7_r)
organ_i_8_r =  find_organ_i(organ, contours_8)
roi_z_8_r = find_roi_slices(images_8, labels_8, organ_i_8_r)
organ_i_9_r =  find_organ_i(organ, contours_9)
roi_z_9_r = find_roi_slices(images_9, labels_9, organ_i_9_r)
organ_i_10_r =  find_organ_i(organ_r, contours_10)
roi_z_10_r = find_roi_slices(images_10, labels_10, organ_i_10_r)

# %% [markdown]
# ## Bladder

# %%
organ = "bladder" #Change this your organ
organ_i_1_b =  find_organ_i(organ, contours_1)
roi_z_1_b = find_roi_slices(images_1, labels_1, organ_i_1_b)
organ_i_3_b =  find_organ_i(organ, contours_3)
roi_z_3_b = find_roi_slices(images_3, labels_3, organ_i_3_b)
organ_i_4_b =  find_organ_i(organ, contours_4)
roi_z_4_b = find_roi_slices(images_4, labels_4, organ_i_4_b)
organ_i_6_b =  find_organ_i(organ, contours_6)
roi_z_6_b = find_roi_slices(images_6, labels_6, organ_i_6_b)
organ_i_7_b =  find_organ_i(organ, contours_7)
roi_z_7_b = find_roi_slices(images_7, labels_7, organ_i_7_b)
organ_i_8_b =  find_organ_i(organ, contours_8)
roi_z_8_b = find_roi_slices(images_8, labels_8, organ_i_8_b)
organ_i_9_b =  find_organ_i(organ, contours_9)
roi_z_9_b = find_roi_slices(images_9, labels_9, organ_i_9_b)
organ_i_10_b =  find_organ_i(organ_r, contours_10)
roi_z_10_b = find_roi_slices(images_10, labels_10, organ_i_10_b)

# %% [markdown]
# ## Fermual Heads

# %%
organ = "Fermual Heads" #Change this your organ
organ_i_1_f =  find_organ_i(organ, contours_1)
roi_z_1_f = find_roi_slices(images_1, labels_1, organ_i_1_f)
organ_i_3_f =  find_organ_i(organ, contours_3)
roi_z_3_f = find_roi_slices(images_3, labels_3, organ_i_3_f)
organ_i_4_f =  find_organ_i(organ, contours_4)
roi_z_4_f = find_roi_slices(images_4, labels_4, organ_i_4_f)
organ_i_6_f =  find_organ_i(organ, contours_6)
roi_z_6_f = find_roi_slices(images_6, labels_6, organ_i_6_f)
organ_i_7_f =  find_organ_i(organ, contours_7)
roi_z_7_f = find_roi_slices(images_7, labels_7, organ_i_7_f)
organ_i_8_f =  find_organ_i(organ, contours_8)
roi_z_8_f = find_roi_slices(images_8, labels_8, organ_i_8_f)
organ_i_9_f =  find_organ_i(organ, contours_9)
roi_z_9_f = find_roi_slices(images_9, labels_9, organ_i_9_f)
organ_i_10_f =  find_organ_i(organ_r, contours_10)
roi_z_10_f = find_roi_slices(images_10, labels_10, organ_i_10_f)

# %% [markdown]
# ## Different Slices

# %% [markdown]
# c = 20
# k = 15
# w = 2
# SD=[c*1.3, c*1.3, c*3]
# assd_contour_rectum_num = labels_num[..., organ_i_num].copy()
# seed = 123
#
# for i in roi_z_num:
#     dx, dy, masknum, t, L, roi_z_num = af_Sobel.assd_Sobel(images_num[i, ...], labels_num[..., organ_i_num][i, ...], voxelsize, a, SD, circles, seed, k, w, images_num, labels_num, organ_i_num, ismax=ismax, smooth=True)
#     dunum = af_Sobel.plotting_assd(dx, dy, masknum, images_num[i, ...], quiver=False, plot=False)
#     assd_contour_rectum_num[i, ...] = dunum
# assd_contour_rectum_num = np.array(assd_contour_rectum_num)
#
# plt.figure(figsize=(15, 15))
# for i in range(25):
#     plt.subplot(5, 5, i + 1)
#     plt.imshow(images_num[roi_z_num[i] , ...], cmap="gray", vmin=-250, vmax=250)
#     plt.contour(assd_contour_rectum_num[roi_z_num[i], ...], levels = [0.5, 1.5, 2.5, 3.5, 4.5], colors="red")
#     plt.contour(labels_num[..., roi_i_num][roi_z_num[i], ...], levels=[0.5, 1.5, 2.5, 3.5, 4.5], colors="blue")
#     plt.xlim(270, 220)
#     plt.ylim(300, 260)
#     blue_patch = mpatches.Patch(color='blue', label="Clinician's contour")
#     red_patch = mpatches.Patch(color='red', label='DU contour with random seed 1')
#     plt.legend(handles=[blue_patch, red_patch])
# plt.axis('off')

# %%
def creating_contour(c, SD_list, organ_i, labels, organ_i, roi_z):
    k = 15
    w = 2
    circles = 3
    ismax=True
    a = 50
    SD=[c*SD_list[0], c*SD_list[1], c*SD_list[2]]
    voxelsize = np.array([0.1076562, 0.1076562, 2.5])

    assd_contour = labels[..., organ_i].copy()
    seed = 72

    for i in roi_z:
        dx, dy, mask, t, L, roi_z = af_Sobel.assd_Sobel(images[i, ...], labels[..., organ_i][i, ...], voxelsize, a, SD, circles, seed, k, w, images, labels, organ_i, ismax=ismax, smooth=True)
        du1 = af_Sobel.plotting_assd(dx, dy, mask, images[i, ...], quiver=False, plot=False) 
        assd_contour[i, ...] = du
    assd_contour = np.array(assd_contour_prostate)
    return assd_contour

# %% [markdown]
# ## Subject 1

# %%
SD_list1 = [1.7, 1.7, 2]

# Prostate
gt_num_p = labels_num[..., organ_i_num_p]

c = 15
auto_prostate_num_15 = creating_contour(c, SD_list1, organ_i_num_p, labels_num, organ_i_num_p, roi_z_num_p)
c = 35
auto_prostate_num_35 = creating_contour(c, SD_list1, organ_i_num_p, labels_num, organ_i_num_p, roi_z_num_p)
c = 40
auto_prostate_num_40 = creating_contour(c, SD_list1, organ_i_num_p, labels_num, organ_i_num_p, roi_z_num_p)
c = 55
auto_prostate_num_55 = creating_contour(c, SD_list1, organ_i_num_p, labels_num, organ_i_num_p, roi_z_num_p)
c = 100
auto_prostate_num_num00 = creating_contour(c, SD_list1, organ_i_num_p, labels_num, organ_i_num_p, roi_z_num_p)

# Rectum
gt_num_r = labels_num[..., organ_i_num_r]

SD_list2 = [1.3, 1.3, 3]
c = 15
auto_rectum_num_num5 = creating_contour(c, SD_list2, organ_i_num_r, labels_num, organ_i_num_r, roi_z_num_r)
c = 35
auto_rectum_num_35 = creating_contour(c, SD_list2, organ_i_num_r, labels_num, organ_i_num_r, roi_z_num_r)
c = 40
auto_rectum_num_40 = creating_contour(c, SD_list2, organ_i_num_r, labels_num, organ_i_num_r, roi_z_num_r)
c = 55
auto_rectum_num_55 = creating_contour(c, SD_list2, organ_i_num_r, labels_num, organ_i_num_r, roi_z_num_r)
c = 100
auto_rectum_num_num00 = creating_contour(c, SD_list2, organ_i_num_r, labels_num, organ_i_num_r, roi_z_num_r)

# bldder
gt_num_b = labels_num[..., organ_i_num_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_num_num5 = creating_contour(c, SD_list3, organ_i_num_b, labels_num, organ_i_num_b, roi_z_num_b)
c = 35
auto_bladder_num_35 = creating_contour(c, SD_list3, organ_i_num_b, labels_num, organ_i_num_b, roi_z_num_b)
c = 40
auto_bladder_num_40 = creating_contour(c, SD_list3, organ_i_num_b, labels_num, organ_i_num_b, roi_z_num_b)
c = 55
auto_bladder_num_55 = creating_contour(c, SD_list3, organ_i_num_b, labels_num, organ_i_num_b, roi_z_num_b)
c = 100
auto_bladder_num_num00 = creating_contour(c, SD_list3, organ_i_num_b, labels_num, organ_i_num_b, roi_z_num_b)


# fermual heads
gt_num_f = labels_num[..., organ_i_num_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_num_num5 = creating_contour(c, SD_list3, organ_i_num_f, labels_num, organ_i_num_f, roi_z_num_f)
c = 35
auto_fh_num_35 = creating_contour(c, SD_list3, organ_i_num_f, labels_num, organ_i_num_f, roi_z_num_f)
c = 40
auto_fh_num_40 = creating_contour(c, SD_list3, organ_i_num_f, labels_num, organ_i_num_f, roi_z_num_f)
c = 55
auto_fh_num_55 = creating_contour(c, SD_list3, organ_i_num_f, labels_num, organ_i_num_f, roi_z_num_f)
c = 100
auto_fh_num_num00 = creating_contour(c, SD_list3, organ_i_num_f, labels_num, organ_i_num_f, roi_z_num_f)

## Exportation
prostate_list = [gt_num_p, auto_prostate_num_15, auto_prostate_num_40, auto_prostate_num_55, auto_prostate_num_15, auto_prostate_num_100]
prostate_name = ["truth_prostate", "auto_prostate_num", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_num_r, auto_rectum_num_15, auto_rectum_num_100, auto_rectum_num_20, auto_rectum_num_30, auto_rectum_num_55]
rectum_name = ["truth_rectum", "auto_rectum_num", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_num_b, auto_bladder_num_15, auto_bladder_num_40, auto_bladder_num_55, auto_bladder_num_15, auto_bladder_num_100]
bladder_name = ["truth_bladder", "auto_bladder_num", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_num_f, auto_fh_num_15, auto_fh_num_100, auto_fh_num_20, auto_fh_num_30, auto_fh_num_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]


RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], color=[prostate_color + rectum_color + bladder_color + fh_color], slices_num, fname=os.path.join(destination_path, 'subject_num_contours.dcm'))

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_1_p = labels_1[..., organ_i_1_p]

c = 15
auto_prostate_1_15 = creating_contour(c, SD_list, organ_i_1_p, labels_1, organ_i_1_p, roi_z_1_p)
c = 35
auto_prostate_1_35 = creating_contour(c, SD_list, organ_i_1_p, labels_1, organ_i_1_p, roi_z_1_p)
c = 40
auto_prostate_1_40 = creating_contour(c, SD_list, organ_i_1_p, labels_1, organ_i_1_p, roi_z_1_p)
c = 55
auto_prostate_1_55 = creating_contour(c, SD_list, organ_i_1_p, labels_1, organ_i_1_p, roi_z_1_p)
c = 100
auto_prostate_1_100 = creating_contour(c, SD_list, organ_i_1_p, labels_1, organ_i_1_p, roi_z_1_p)

# Rectum
gt_1_r = labels_1[..., organ_i_1_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_1_15 = creating_contour(c, SD_list, organ_i_1_r, labels_1, organ_i_1_r, roi_z_1_r)
c = 35
auto_rectum_1_35 = creating_contour(c, SD_list, organ_i_1_r, labels_1, organ_i_1_r, roi_z_1_r)
c = 40
auto_rectum_1_40 = creating_contour(c, SD_list, organ_i_1_r, labels_1, organ_i_1_r, roi_z_1_r)
c = 55
auto_rectum_1_55 = creating_contour(c, SD_list, organ_i_1_r, labels_1, organ_i_1_r, roi_z_1_r)
c = 100
auto_rectum_1_100 = creating_contour(c, SD_list, organ_i_1_r, labels_1, organ_i_1_r, roi_z_1_r)

# bldder
gt_1_b = labels_1[..., organ_i_1_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_1_15 = creating_contour(c, SD_list3, organ_i_1_b, labels_1, organ_i_1_b, roi_z_1_b)
c = 35
auto_bladder_1_35 = creating_contour(c, SD_list3, organ_i_1_b, labels_1, organ_i_1_b, roi_z_1_b)
c = 40
auto_bladder_1_40 = creating_contour(c, SD_list3, organ_i_1_b, labels_1, organ_i_1_b, roi_z_1_b)
c = 55
auto_bladder_1_55 = creating_contour(c, SD_list3, organ_i_1_b, labels_1, organ_i_1_b, roi_z_1_b)
c = 100
auto_bladder_1_100 = creating_contour(c, SD_list3, organ_i_1_b, labels_1, organ_i_1_b, roi_z_1_b)


# fermual heads
gt_1_f = labels_1[..., organ_i_1_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_1_15 = creating_contour(c, SD_list3, organ_i_1_f, labels_1, organ_i_1_f, roi_z_1_f)
c = 35
auto_fh_1_35 = creating_contour(c, SD_list3, organ_i_1_f, labels_1, organ_i_1_f, roi_z_1_f)
c = 40
auto_fh_1_40 = creating_contour(c, SD_list3, organ_i_1_f, labels_1, organ_i_1_f, roi_z_1_f)
c = 55
auto_fh_1_55 = creating_contour(c, SD_list3, organ_i_1_f, labels_1, organ_i_1_f, roi_z_1_f)
c = 100
auto_fh_1_100 = creating_contour(c, SD_list3, organ_i_1_f, labels_1, organ_i_1_f, roi_z_1_f)



## Exportation
prostate_list = [gt_1_p, auto_prostate_1_15, auto_prostate_1_35, auto_prostate_1_40, auto_prostate_1_55, auto_prostate_1_100]
prostate_name = ["truth_prostate", "auto_prostate_1", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_1_r, auto_rectum_1_15, auto_rectum_1_35, auto_rectum_1_40, auto_rectum_1_55, auto_rectum_1_100]
rectum_name = ["truth_rectum", "auto_rectum_1", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_1_b, auto_bladder_1_15, auto_bladder_1_40, auto_bladder_1_55, auto_bladder_1_15, auto_bladder_1_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_1_f, auto_fh_1_15, auto_fh_1_100, auto_fh_1_20, auto_fh_1_30, auto_fh_1_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]


RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], color=[prostate_color + rectum_color + bladder_color + fh_color], slices_1, fname=os.path.join(destination_path, 'subject_1_contours.dcm'))

# %% [markdown]
# ## Subject 3:

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_3_p = labels_3[..., organ_i_3_p]

c = 15
auto_prostate_3_15 = creating_contour(c, SD_list, organ_i_3_p, labels_3, organ_i_3_p, roi_z_3_p)
c = 35
auto_prostate_3_35 = creating_contour(c, SD_list, organ_i_3_p, labels_3, organ_i_3_p, roi_z_3_p)
c = 40
auto_prostate_3_40 = creating_contour(c, SD_list, organ_i_3_p, labels_3, organ_i_3_p, roi_z_3_p)
c = 55
auto_prostate_3_55 = creating_contour(c, SD_list, organ_i_3_p, labels_3, organ_i_3_p, roi_z_3_p)
c = 100
auto_prostate_3_300 = creating_contour(c, SD_list, organ_i_3_p, labels_3, organ_i_3_p, roi_z_3_p)

# Rectum
gt_3_r = labels_3[..., organ_i_3_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_3_35 = creating_contour(c, SD_list, organ_i_3_r, labels_3, organ_i_3_r, roi_z_3_r)
c = 35
auto_rectum_3_35 = creating_contour(c, SD_list, organ_i_3_r, labels_3, organ_i_3_r, roi_z_3_r)
c = 40
auto_rectum_3_40 = creating_contour(c, SD_list, organ_i_3_r, labels_3, organ_i_3_r, roi_z_3_r)
c = 55
auto_rectum_3_55 = creating_contour(c, SD_list, organ_i_3_r, labels_3, organ_i_3_r, roi_z_3_r)
c = 100
auto_rectum_3_300 = creating_contour(c, SD_list, organ_i_3_r, labels_3, organ_i_3_r, roi_z_3_r)


# bldder
gt_3_b = labels_3[..., organ_i_3_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_3_15 = creating_contour(c, SD_list3, organ_i_3_b, labels_3, organ_i_3_b, roi_z_3_b)
c = 35
auto_bladder_3_35 = creating_contour(c, SD_list3, organ_i_3_b, labels_3, organ_i_3_b, roi_z_3_b)
c = 40
auto_bladder_3_40 = creating_contour(c, SD_list3, organ_i_3_b, labels_3, organ_i_3_b, roi_z_3_b)
c = 55
auto_bladder_3_55 = creating_contour(c, SD_list3, organ_i_3_b, labels_3, organ_i_3_b, roi_z_3_b)
c = 100
auto_bladder_3_100 = creating_contour(c, SD_list3, organ_i_3_b, labels_3, organ_i_3_b, roi_z_3_b)


# fermual heads
gt_3_f = labels_3[..., organ_i_3_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_3_15 = creating_contour(c, SD_list3, organ_i_3_f, labels_3, organ_i_3_f, roi_z_3_f)
c = 35
auto_fh_3_35 = creating_contour(c, SD_list3, organ_i_3_f, labels_3, organ_i_3_f, roi_z_3_f)
c = 40
auto_fh_3_40 = creating_contour(c, SD_list3, organ_i_3_f, labels_3, organ_i_3_f, roi_z_3_f)
c = 55
auto_fh_3_55 = creating_contour(c, SD_list3, organ_i_3_f, labels_3, organ_i_3_f, roi_z_3_f)
c = 100
auto_fh_3_100 = creating_contour(c, SD_list3, organ_i_3_f, labels_3, organ_i_3_f, roi_z_3_f)



## Exportation
prostate_list = [gt_3_p, auto_prostate_3_35, auto_prostate_3_15,  auto_prostate_3_55, auto_prostate_3_40, auto_prostate_3_100]
prostate_name = ["truth_prostate", "auto_prostate_3", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_3_r, auto_rectum_3_15, auto_rectum_3_30, auto_rectum_3_100, auto_rectum_3_55, auto_rectum_3_20]
rectum_name = ["truth_rectum", "auto_rectum_3", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_3_b, auto_bladder_3_15, auto_bladder_3_40, auto_bladder_3_55, auto_bladder_3_15, auto_bladder_3_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_3_f, auto_fh_3_15, auto_fh_3_100, auto_fh_3_20, auto_fh_3_30, auto_fh_3_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]

RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], color=[prostate_color + rectum_color + bladder_color + fh_color], slices_3, fname=os.path.join(destination_path, 'subject_3_contours.dcm'))

# %% [markdown]
# ## Subject 4

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_4_p = labels_4[..., organ_i_4_p]

c = 15
auto_prostate_4_15 = creating_contour(c, SD_list, organ_i_4_p, labels_4, organ_i_4_p, roi_z_4_p)
c = 35
auto_prostate_4_35 = creating_contour(c, SD_list, organ_i_4_p, labels_4, organ_i_4_p, roi_z_4_p)
c = 40
auto_prostate_4_40 = creating_contour(c, SD_list, organ_i_4_p, labels_4, organ_i_4_p, roi_z_4_p)
c = 55
auto_prostate_4_55 = creating_contour(c, SD_list, organ_i_4_p, labels_4, organ_i_4_p, roi_z_4_p)
c = 100
auto_prostate_4_400 = creating_contour(c, SD_list, organ_i_4_p, labels_4, organ_i_4_p, roi_z_4_p)

# Rectum
gt_4_r = labels_4[..., organ_i_4_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_4_45 = creating_contour(c, SD_list, organ_i_4_r, labels_4, organ_i_4_r, roi_z_4_r)
c = 35
auto_rectum_4_35 = creating_contour(c, SD_list, organ_i_4_r, labels_4, organ_i_4_r, roi_z_4_r)
c = 40
auto_rectum_4_40 = creating_contour(c, SD_list, organ_i_4_r, labels_4, organ_i_4_r, roi_z_4_r)
c = 55
auto_rectum_4_55 = creating_contour(c, SD_list, organ_i_4_r, labels_4, organ_i_4_r, roi_z_4_r)
c = 100
auto_rectum_4_400 = creating_contour(c, SD_list, organ_i_4_r, labels_4, organ_i_4_r, roi_z_4_r)

# bldder
gt_4_b = labels_4[..., organ_i_4_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_4_15 = creating_contour(c, SD_list3, organ_i_4_b, labels_4, organ_i_4_b, roi_z_4_b)
c = 35
auto_bladder_4_35 = creating_contour(c, SD_list3, organ_i_4_b, labels_4, organ_i_4_b, roi_z_4_b)
c = 40
auto_bladder_4_40 = creating_contour(c, SD_list3, organ_i_4_b, labels_4, organ_i_4_b, roi_z_4_b)
c = 55
auto_bladder_4_55 = creating_contour(c, SD_list3, organ_i_4_b, labels_4, organ_i_4_b, roi_z_4_b)
c = 100
auto_bladder_4_100 = creating_contour(c, SD_list3, organ_i_4_b, labels_4, organ_i_4_b, roi_z_4_b)


# fermual heads
gt_4_f = labels_4[..., organ_i_4_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_4_15 = creating_contour(c, SD_list3, organ_i_4_f, labels_4, organ_i_4_f, roi_z_4_f)
c = 35
auto_fh_4_35 = creating_contour(c, SD_list3, organ_i_4_f, labels_4, organ_i_4_f, roi_z_4_f)
c = 40
auto_fh_4_40 = creating_contour(c, SD_list3, organ_i_4_f, labels_4, organ_i_4_f, roi_z_4_f)
c = 55
auto_fh_4_55 = creating_contour(c, SD_list3, organ_i_4_f, labels_4, organ_i_4_f, roi_z_4_f)
c = 100
auto_fh_4_100 = creating_contour(c, SD_list3, organ_i_4_f, labels_4, organ_i_4_f, roi_z_4_f)

## Exportation
prostate_list = [gt_4_p, auto_prostate_4_15, auto_prostate_4_35, auto_prostate_4_40, auto_prostate_4_55, auto_prostate_4_100]
prostate_name = ["truth_prostate", "auto_prostate_4", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_4_r, auto_rectum_4_15, auto_rectum_4_30, auto_rectum_4_55, auto_rectum_4_20, auto_rectum_4_100]
rectum_name = ["truth_rectum", "auto_rectum_4", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_4_b, auto_bladder_4_15, auto_bladder_4_40, auto_bladder_4_55, auto_bladder_4_15, auto_bladder_4_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_4_f, auto_fh_4_15, auto_fh_4_100, auto_fh_4_20, auto_fh_4_30, auto_fh_4_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]


RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], slices_4, fname=os.path.join(destination_path, 'subject_4_contours.dcm'))

# %% [markdown]
# ## Subject 6

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_6_p = labels_6[..., organ_i_6_p]

c = 15
auto_prostate_6_15 = creating_contour(c, SD_list, organ_i_6_p, labels_6, organ_i_6_p, roi_z_6_p)
c = 35
auto_prostate_6_35 = creating_contour(c, SD_list, organ_i_6_p, labels_6, organ_i_6_p, roi_z_6_p)
c = 40
auto_prostate_6_40 = creating_contour(c, SD_list, organ_i_6_p, labels_6, organ_i_6_p, roi_z_6_p)
c = 55
auto_prostate_6_55 = creating_contour(c, SD_list, organ_i_6_p, labels_6, organ_i_6_p, roi_z_6_p)
c = 100
auto_prostate_6_600 = creating_contour(c, SD_list, organ_i_6_p, labels_6, organ_i_6_p, roi_z_6_p)

# Rectum
gt_6_r = labels_6[..., organ_i_6_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_6_65 = creating_contour(c, SD_list, organ_i_6_r, labels_6, organ_i_6_r, roi_z_6_r)
c = 35
auto_rectum_6_35 = creating_contour(c, SD_list, organ_i_6_r, labels_6, organ_i_6_r, roi_z_6_r)
c = 40
auto_rectum_6_40 = creating_contour(c, SD_list, organ_i_6_r, labels_6, organ_i_6_r, roi_z_6_r)
c = 55
auto_rectum_6_55 = creating_contour(c, SD_list, organ_i_6_r, labels_6, organ_i_6_r, roi_z_6_r)
c = 100
auto_rectum_6_600 = creating_contour(c, SD_list, organ_i_6_r, labels_6, organ_i_6_r, roi_z_6_r)

# bldder
gt_6_b = labels_6[..., organ_i_6_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_6_15 = creating_contour(c, SD_list3, organ_i_6_b, labels_6, organ_i_6_b, roi_z_6_b)
c = 35
auto_bladder_6_35 = creating_contour(c, SD_list3, organ_i_6_b, labels_6, organ_i_6_b, roi_z_6_b)
c = 40
auto_bladder_6_40 = creating_contour(c, SD_list3, organ_i_6_b, labels_6, organ_i_6_b, roi_z_6_b)
c = 55
auto_bladder_6_55 = creating_contour(c, SD_list3, organ_i_6_b, labels_6, organ_i_6_b, roi_z_6_b)
c = 100
auto_bladder_6_100 = creating_contour(c, SD_list3, organ_i_6_b, labels_6, organ_i_6_b, roi_z_6_b)


# fermual heads
gt_6_f = labels_6[..., organ_i_6_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_6_15 = creating_contour(c, SD_list3, organ_i_6_f, labels_6, organ_i_6_f, roi_z_6_f)
c = 35
auto_fh_6_35 = creating_contour(c, SD_list3, organ_i_6_f, labels_6, organ_i_6_f, roi_z_6_f)
c = 40
auto_fh_6_40 = creating_contour(c, SD_list3, organ_i_6_f, labels_6, organ_i_6_f, roi_z_6_f)
c = 55
auto_fh_6_55 = creating_contour(c, SD_list3, organ_i_6_f, labels_6, organ_i_6_f, roi_z_6_f)
c = 100
auto_fh_6_100 = creating_contour(c, SD_list3, organ_i_6_f, labels_6, organ_i_6_f, roi_z_6_f)





## Exportation
prostate_list = [gt_6_p, auto_prostate_6_15, auto_prostate_6_35, auto_prostate_6_40, auto_prostate_6_55, auto_prostate_6_100]
prostate_name = ["truth_prostate", "auto_prostate_6", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_6_r, auto_rectum_6_15, auto_rectum_6_20, auto_rectum_6_30, auto_rectum_6_55, auto_rectum_6_600]
rectum_name = ["truth_rectum", "auto_rectum_6", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_6_b, auto_bladder_6_15, auto_bladder_6_40, auto_bladder_6_55, auto_bladder_6_15, auto_bladder_6_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_6_f, auto_fh_6_15, auto_fh_6_100, auto_fh_6_20, auto_fh_6_30, auto_fh_6_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]


RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], slices_6, fname=os.path.join(destination_path, 'subject_6_contours.dcm'))

# %% [markdown]
# ## Subject 7

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_7_p = labels_7[..., organ_i_7_p]

c = 15
auto_prostate_7_15 = creating_contour(c, SD_list, organ_i_7_p, labels_7, organ_i_7_p, roi_z_7_p)
c = 35
auto_prostate_7_35 = creating_contour(c, SD_list, organ_i_7_p, labels_7, organ_i_7_p, roi_z_7_p)
c = 40
auto_prostate_7_40 = creating_contour(c, SD_list, organ_i_7_p, labels_7, organ_i_7_p, roi_z_7_p)
c = 55
auto_prostate_7_55 = creating_contour(c, SD_list, organ_i_7_p, labels_7, organ_i_7_p, roi_z_7_p)
c = 100
auto_prostate_7_700 = creating_contour(c, SD_list, organ_i_7_p, labels_7, organ_i_7_p, roi_z_7_p)

# Rectum
gt_7_r = labels_7[..., organ_i_7_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_7_75 = creating_contour(c, SD_list, organ_i_7_r, labels_7, organ_i_7_r, roi_z_7_r)
c = 35
auto_rectum_7_35 = creating_contour(c, SD_list, organ_i_7_r, labels_7, organ_i_7_r, roi_z_7_r)
c = 40
auto_rectum_7_40 = creating_contour(c, SD_list, organ_i_7_r, labels_7, organ_i_7_r, roi_z_7_r)
c = 55
auto_rectum_7_55 = creating_contour(c, SD_list, organ_i_7_r, labels_7, organ_i_7_r, roi_z_7_r)
c = 100
auto_rectum_7_700 = creating_contour(c, SD_list, organ_i_7_r, labels_7, organ_i_7_r, roi_z_7_r)

# bldder
gt_7_b = labels_7[..., organ_i_7_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_7_15 = creating_contour(c, SD_list3, organ_i_7_b, labels_7, organ_i_7_b, roi_z_7_b)
c = 35
auto_bladder_7_35 = creating_contour(c, SD_list3, organ_i_7_b, labels_7, organ_i_7_b, roi_z_7_b)
c = 40
auto_bladder_7_40 = creating_contour(c, SD_list3, organ_i_7_b, labels_7, organ_i_7_b, roi_z_7_b)
c = 55
auto_bladder_7_55 = creating_contour(c, SD_list3, organ_i_7_b, labels_7, organ_i_7_b, roi_z_7_b)
c = 100
auto_bladder_7_100 = creating_contour(c, SD_list3, organ_i_7_b, labels_7, organ_i_7_b, roi_z_7_b)


# fermual heads
gt_7_f = labels_7[..., organ_i_7_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_7_15 = creating_contour(c, SD_list3, organ_i_7_f, labels_7, organ_i_7_f, roi_z_7_f)
c = 35
auto_fh_7_35 = creating_contour(c, SD_list3, organ_i_7_f, labels_7, organ_i_7_f, roi_z_7_f)
c = 40
auto_fh_7_40 = creating_contour(c, SD_list3, organ_i_7_f, labels_7, organ_i_7_f, roi_z_7_f)
c = 55
auto_fh_7_55 = creating_contour(c, SD_list3, organ_i_7_f, labels_7, organ_i_7_f, roi_z_7_f)
c = 100
auto_fh_7_100 = creating_contour(c, SD_list3, organ_i_7_f, labels_7, organ_i_7_f, roi_z_7_f)


## Exportation
prostate_list = [gt_7_p, auto_prostate_7_40, auto_prostate_7_55, auto_prostate_7_15, auto_prostate_7_35, auto_prostate_7_100]
prostate_name = ["truth_prostate", "auto_prostate_7", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_7_r, auto_rectum_7_15, auto_rectum_7_20, auto_rectum_7_30, auto_rectum_7_55, auto_rectum_7_700]
rectum_name = ["truth_rectum", "auto_rectum_7", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_7_b, auto_bladder_7_15, auto_bladder_7_40, auto_bladder_7_55, auto_bladder_7_15, auto_bladder_7_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_7_f, auto_fh_7_15, auto_fh_7_100, auto_fh_7_20, auto_fh_7_30, auto_fh_7_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]


RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], slices_7, fname=os.path.join(destination_path, 'subject_7_contours.dcm'))

# %% [markdown]
# ## Subject 8

# %%
SD_list = [1.7, 1.7, 2]

# Prostate
gt_8_p = labels_8[..., organ_i_8_p]

c = 15
auto_prostate_8_15 = creating_contour(c, SD_list, organ_i_8_p, labels_8, organ_i_8_p, roi_z_8_p)
c = 35
auto_prostate_8_35 = creating_contour(c, SD_list, organ_i_8_p, labels_8, organ_i_8_p, roi_z_8_p)
c = 40
auto_prostate_8_40 = creating_contour(c, SD_list, organ_i_8_p, labels_8, organ_i_8_p, roi_z_8_p)
c = 55
auto_prostate_8_55 = creating_contour(c, SD_list, organ_i_8_p, labels_8, organ_i_8_p, roi_z_8_p)
c = 100
auto_prostate_8_800 = creating_contour(c, SD_list, organ_i_8_p, labels_8, organ_i_8_p, roi_z_8_p)

# Rectum
gt_8_r = labels_8[..., organ_i_8_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_8_85 = creating_contour(c, SD_list, organ_i_8_r, labels_8, organ_i_8_r, roi_z_8_r)
c = 35
auto_rectum_8_35 = creating_contour(c, SD_list, organ_i_8_r, labels_8, organ_i_8_r, roi_z_8_r)
c = 40
auto_rectum_8_40 = creating_contour(c, SD_list, organ_i_8_r, labels_8, organ_i_8_r, roi_z_8_r)
c = 55
auto_rectum_8_55 = creating_contour(c, SD_list, organ_i_8_r, labels_8, organ_i_8_r, roi_z_8_r)
c = 100
auto_rectum_8_800 = creating_contour(c, SD_list, organ_i_8_r, labels_8, organ_i_8_r, roi_z_8_r)

# bldder
gt_8_b = labels_8[..., organ_i_8_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_8_15 = creating_contour(c, SD_list3, organ_i_8_b, labels_8, organ_i_8_b, roi_z_8_b)
c = 35
auto_bladder_8_35 = creating_contour(c, SD_list3, organ_i_8_b, labels_8, organ_i_8_b, roi_z_8_b)
c = 40
auto_bladder_8_40 = creating_contour(c, SD_list3, organ_i_8_b, labels_8, organ_i_8_b, roi_z_8_b)
c = 55
auto_bladder_8_55 = creating_contour(c, SD_list3, organ_i_8_b, labels_8, organ_i_8_b, roi_z_8_b)
c = 100
auto_bladder_8_100 = creating_contour(c, SD_list3, organ_i_8_b, labels_8, organ_i_8_b, roi_z_8_b)


# fermual heads
gt_8_f = labels_8[..., organ_i_8_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_8_15 = creating_contour(c, SD_list3, organ_i_8_f, labels_8, organ_i_8_f, roi_z_8_f)
c = 35
auto_fh_8_35 = creating_contour(c, SD_list3, organ_i_8_f, labels_8, organ_i_8_f, roi_z_8_f)
c = 40
auto_fh_8_40 = creating_contour(c, SD_list3, organ_i_8_f, labels_8, organ_i_8_f, roi_z_8_f)
c = 55
auto_fh_8_55 = creating_contour(c, SD_list3, organ_i_8_f, labels_8, organ_i_8_f, roi_z_8_f)
c = 100
auto_fh_8_100 = creating_contour(c, SD_list3, organ_i_8_f, labels_8, organ_i_8_f, roi_z_8_f)





## Exportation
prostate_list = [gt_8_p, auto_prostate_8_15, auto_prostate_8_100, auto_prostate_8_40, auto_prostate_8_35, auto_prostate_8_55]
prostate_name = ["truth_prostate", "auto_prostate_8", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_8_r, auto_rectum_8_15, auto_rectum_8_100, auto_rectum_8_20, auto_rectum_8_30, auto_rectum_8_55, ]
rectum_name = ["truth_rectum", "auto_rectum_8", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_8_b, auto_bladder_8_15, auto_bladder_8_40, auto_bladder_8_55, auto_bladder_8_15, auto_bladder_8_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_8_f, auto_fh_8_15, auto_fh_8_100, auto_fh_8_20, auto_fh_8_30, auto_fh_8_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]


RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], slices_8, fname=os.path.join(destination_path, 'subject_8_contours.dcm'))

# %% [markdown]
# ## Subject 9

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_9_p = labels_9[..., organ_i_9_p]

c = 15
auto_prostate_9_15 = creating_contour(c, SD_list, organ_i_9_p, labels_9, organ_i_9_p, roi_z_9_p)
c = 35
auto_prostate_9_35 = creating_contour(c, SD_list, organ_i_9_p, labels_9, organ_i_9_p, roi_z_9_p)
c = 40
auto_prostate_9_40 = creating_contour(c, SD_list, organ_i_9_p, labels_9, organ_i_9_p, roi_z_9_p)
c = 55
auto_prostate_9_55 = creating_contour(c, SD_list, organ_i_9_p, labels_9, organ_i_9_p, roi_z_9_p)
c = 100
auto_prostate_9_900 = creating_contour(c, SD_list, organ_i_9_p, labels_9, organ_i_9_p, roi_z_9_p)

# Rectum
gt_9_r = labels_9[..., organ_i_9_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_9_95 = creating_contour(c, SD_list, organ_i_9_r, labels_9, organ_i_9_r, roi_z_9_r)
c = 35
auto_rectum_9_35 = creating_contour(c, SD_list, organ_i_9_r, labels_9, organ_i_9_r, roi_z_9_r)
c = 40
auto_rectum_9_40 = creating_contour(c, SD_list, organ_i_9_r, labels_9, organ_i_9_r, roi_z_9_r)
c = 55
auto_rectum_9_55 = creating_contour(c, SD_list, organ_i_9_r, labels_9, organ_i_9_r, roi_z_9_r)
c = 100
auto_rectum_9_900 = creating_contour(c, SD_list, organ_i_9_r, labels_9, organ_i_9_r, roi_z_9_r)

# bldder
gt_9_b = labels_9[..., organ_i_9_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_9_15 = creating_contour(c, SD_list3, organ_i_9_b, labels_9, organ_i_9_b, roi_z_9_b)
c = 35
auto_bladder_9_35 = creating_contour(c, SD_list3, organ_i_9_b, labels_9, organ_i_9_b, roi_z_9_b)
c = 40
auto_bladder_9_40 = creating_contour(c, SD_list3, organ_i_9_b, labels_9, organ_i_9_b, roi_z_9_b)
c = 55
auto_bladder_9_55 = creating_contour(c, SD_list3, organ_i_9_b, labels_9, organ_i_9_b, roi_z_9_b)
c = 100
auto_bladder_9_100 = creating_contour(c, SD_list3, organ_i_9_b, labels_9, organ_i_9_b, roi_z_9_b)


# fermual heads
gt_9_f = labels_9[..., organ_i_9_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_9_15 = creating_contour(c, SD_list3, organ_i_9_f, labels_9, organ_i_9_f, roi_z_9_f)
c = 35
auto_fh_9_35 = creating_contour(c, SD_list3, organ_i_9_f, labels_9, organ_i_9_f, roi_z_9_f)
c = 40
auto_fh_9_40 = creating_contour(c, SD_list3, organ_i_9_f, labels_9, organ_i_9_f, roi_z_9_f)
c = 55
auto_fh_9_55 = creating_contour(c, SD_list3, organ_i_9_f, labels_9, organ_i_9_f, roi_z_9_f)
c = 100
auto_fh_9_100 = creating_contour(c, SD_list3, organ_i_9_f, labels_9, organ_i_9_f, roi_z_9_f)



## Exportation
prostate_list = [gt_9_p, auto_prostate_9_15, auto_prostate_9_55, auto_prostate_9_100, auto_prostate_9_35, auto_prostate_9_40]
prostate_name = ["truth_prostate", "auto_prostate_9", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_9_r, auto_rectum_9_30, auto_rectum_9_55, auto_rectum_9_15, auto_rectum_9_20, auto_rectum_9_100]
rectum_name = ["truth_rectum", "auto_rectum_9", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_9_b, auto_bladder_9_15, auto_bladder_9_40, auto_bladder_9_55, auto_bladder_9_15, auto_bladder_9_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_9_f, auto_fh_9_15, auto_fh_9_100, auto_fh_9_20, auto_fh_9_30, auto_fh_9_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]



RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name], slices_9, fname=os.path.join(destination_path, 'subject_9_contours.dcm'))

# %% [markdown]
# ## Subject 10

# %%
SD_list = [1.3, 1.3, 3]

# Prostate
gt_10_p = labels_10[..., organ_i_10_p]

c = 15
auto_prostate_10_15 = creating_contour(c, SD_list, organ_i_10_p, labels_10, organ_i_10_p, roi_z_10_p)
c = 35
auto_prostate_10_35 = creating_contour(c, SD_list, organ_i_10_p, labels_10, organ_i_10_p, roi_z_10_p)
c = 40
auto_prostate_10_40 = creating_contour(c, SD_list, organ_i_10_p, labels_10, organ_i_10_p, roi_z_10_p)
c = 55
auto_prostate_10_55 = creating_contour(c, SD_list, organ_i_10_p, labels_10, organ_i_10_p, roi_z_10_p)
c = 100
auto_prostate_10_1000 = creating_contour(c, SD_list, organ_i_10_p, labels_10, organ_i_10_p, roi_z_10_p)

# Rectum
gt_10_r = labels_10[..., organ_i_10_r]

SD_list = [1.3, 1.3, 3]
c = 15
auto_rectum_10_105 = creating_contour(c, SD_list, organ_i_10_r, labels_10, organ_i_10_r, roi_z_10_r)
c = 35
auto_rectum_10_35 = creating_contour(c, SD_list, organ_i_10_r, labels_10, organ_i_10_r, roi_z_10_r)
c = 40
auto_rectum_10_40 = creating_contour(c, SD_list, organ_i_10_r, labels_10, organ_i_10_r, roi_z_10_r)
c = 55
auto_rectum_10_55 = creating_contour(c, SD_list, organ_i_10_r, labels_10, organ_i_10_r, roi_z_10_r)
c = 100
auto_rectum_10_1000 = creating_contour(c, SD_list, organ_i_10_r, labels_10, organ_i_10_r, roi_z_10_r)

# bldder
gt_10_b = labels_10[..., organ_i_10_b]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_bladder_10_15 = creating_contour(c, SD_list3, organ_i_10_b, labels_10, organ_i_10_b, roi_z_10_b)
c = 35
auto_bladder_10_35 = creating_contour(c, SD_list3, organ_i_10_b, labels_10, organ_i_10_b, roi_z_10_b)
c = 40
auto_bladder_10_40 = creating_contour(c, SD_list3, organ_i_10_b, labels_10, organ_i_10_b, roi_z_10_b)
c = 55
auto_bladder_10_55 = creating_contour(c, SD_list3, organ_i_10_b, labels_10, organ_i_10_b, roi_z_10_b)
c = 100
auto_bladder_10_100 = creating_contour(c, SD_list3, organ_i_10_b, labels_10, organ_i_10_b, roi_z_10_b)


# fermual heads
gt_10_f = labels_10[..., organ_i_10_f]

SD_list3 = [0.7, 0.7, 2]
c = 15
auto_fh_10_15 = creating_contour(c, SD_list3, organ_i_10_f, labels_10, organ_i_10_f, roi_z_10_f)
c = 35
auto_fh_10_35 = creating_contour(c, SD_list3, organ_i_10_f, labels_10, organ_i_10_f, roi_z_10_f)
c = 40
auto_fh_10_40 = creating_contour(c, SD_list3, organ_i_10_f, labels_10, organ_i_10_f, roi_z_10_f)
c = 55
auto_fh_10_55 = creating_contour(c, SD_list3, organ_i_10_f, labels_10, organ_i_10_f, roi_z_10_f)
c = 100
auto_fh_10_100 = creating_contour(c, SD_list3, organ_i_10_f, labels_10, organ_i_10_f, roi_z_10_f)




## Exportation
prostate_list = [gt_10_p, auto_prostate_10_55, auto_prostate_10_100, auto_prostate_10_15, auto_prostate_10_35, auto_prostate_10_40]
prostate_name = ["truth_prostate", "auto_prostate_10", "auto_prostate_2", "auto_prostate_3", "auto_prostate_4", "auto_prostate_5"]
prostate_color = ["red", "green", "purple", "yellow", "blue", "orange"]
rectum_list = [gt_10_r, auto_rectum_10_55, auto_rectum_10_100, auto_rectum_10_20, auto_rectum_10_30, auto_rectum_10_15]
rectum_name = ["truth_rectum", "auto_rectum_10", "auto_rectum_2", "auto_rectum_3", "auto_rectum_4", "auto_rectum_5"]
rectum_color = ["red", "purple", "yellow", "blue", "orange", "green"]
bladder_list = [gt_10_b, auto_bladder_10_15, auto_bladder_10_40, auto_bladder_10_55, auto_bladder_10_15, auto_bladder_10_100]
bladder_name = ["truth_bladder", "auto_bladder_1", "auto_bladder_2", "auto_bladder_3", "auto_bladder_4", "auto_bladder_5"]
bladder_color = ["red", "green", "purple", "yellow", "blue", "orange"]
fh_list = [gt_10_f, auto_fh_10_15, auto_fh_10_100, auto_fh_10_20, auto_fh_10_30, auto_fh_10_55]
fh_name = ["truth_fh", "auto_fh_num", "auto_fh_2", "auto_fh_3", "auto_fh_4", "auto_fh_5"]
fh_color = ["red", "purple", "yellow", "blue", "orange", "green"]



RTStruct([prostate_list + rectum_list + bladder_list + fh_list], [prostate_name + rectum_name + bladder_name + fh_name] slices_10, fname=os.path.join(destination_path, 'subject_10_contours.dcm'))
